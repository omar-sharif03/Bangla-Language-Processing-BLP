# %%
# !pip install editdistance
# Out:
# Requirement already satisfied: editdistance in /usr/local/lib/python3.6/dist-packages (0.5.2)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import os
import sys

import pickle
import tensorflow as tf
import numpy as np

import warnings
warnings.filterwarnings("ignore")
from skimage import io, transform
import cv2
from skimage import img_as_uint

import editdistance
import get_feature_vector as gfv;

from sklearn.model_selection import train_test_split

from skimage import morphology, util
from skimage import color
from skimage import filters
from skimage import morphology as mp;
import AdjustImage as ai

LOGDIR = "model_lowdropout/"

# %% [markdown]
# ## Load input and output data

# %%
#restore the input array and label array form file
myFilei = "train_input.txt";
myFileo = "train_output.txt";
myFiletsti = "test_input.txt";
myFiletsto = "test_output.txt";
with open(myFilei, 'rb') as f:
    train_input = pickle.load(f);
    print("Train input SuccessFully Loaded");
with open(myFileo, 'rb') as f:
    train_output = pickle.load(f);
    print("Train output SuccessFully Loaded");
with open(myFiletsti, 'rb') as f:
    test_input = pickle.load(f);
    print("Test input SuccessFully Loaded");
with open(myFiletsto, 'rb') as f:
    test_output = pickle.load(f);
    print("Test output SuccessFully Loaded");
    
print(len(train_output));
print(len(test_output));
print(len(test_output)+len(train_output));
#print(train_output);
# Out:
# Train input SuccessFully Loaded
# Train output SuccessFully Loaded
# Test input SuccessFully Loaded
# Test output SuccessFully Loaded
# 930
# 465
# 1395

# %% [markdown]
# Create a function that will convert output array to 2D sparse tensor

# %%
def toSparse(output_label):
    #put ground truth text into sparse tuple for ctc_loss
    
    indices = [];
    values = [];
    shape = [len(output_label), 0] #shape[1] must be max(labelList)
    
    #go over all batches
    for (batchElement, label) in enumerate(output_label):
        #get list of labels
        labels = [c for c in label];
        
        #sparse tensor must have size of max labels
        if(len(labels) > shape[1]):
            shape[1] = len(labels)
            
        #put each label on sparse tensor
        for(i, lbl) in enumerate(labels):
            indices.append([batchElement, i]);
            values.append(lbl);
    
    return (indices, values, shape);

# %% [markdown]
# Create a funciton to decode the output labels into string

# %%
myFile = 'borno.txt';
with open(myFile , 'rb') as f:
    rs_borno = pickle.load(f);

#sort the arrayz
rs_borno.sort();
#print(rs_borno);

def to_string(ar, rs_borno):
    #print(ar);
    ans = "";
    
    #ans2 = list();
    vowel_dep = ['া', 'ি', 'ী', 'ু', 'ূ', 'ৃ', 'ে', 'ৈ', 'ো', 'ৌ', 'ং', '্'];
    char_set = list();
    
    indx = 0 ;
    character = "";
    while(indx<len(ar)):
        ch = rs_borno[ar[indx]];
        
        if(ch != '্'):
            if(len(character) > 0):
                char_set.append(character);
                character = "";
            
            if(ch not in vowel_dep):
                character += ch;
            
            else:
                char_set.append(ch);
        else:
            character += ch;
            if(indx+1 < len(ar)):
                indx+=1;
                character += rs_borno[ar[indx]];
        indx+=1;
    
    if(len(character)>0):
        char_set.append(character);
    #print(char_set);
    ind = 0;
    while(ind<len(char_set)):
        ch = char_set[ind];
        if(ch == 'ে'):
            if(ind+2<len(char_set) and char_set[ind+2] == 'া'):
                ans += char_set[ind+1];
                ans += 'ো';
                ind+=2;
            elif(ind+2<len(char_set) and char_set[ind+2] == 'ী'):
                ans += char_set[ind+1];
                ans += 'ৌ';
                ind+=2;
            else:
                if(ind+1<len(char_set)):
                    ans += char_set[ind+1];
                    ind+=1;
                ans += ch;
        elif(ch == 'ি' or ch =='ৈ'):
            if(ind+1<len(char_set)):
                ans += char_set[ind+1];
                ind+=1;
            ans += ch;
        else:
            ans += ch;
        ind+=1;
    return ans; #, ans2;

#test form http://localhost:8888/notebooks/Normal_practice/Bangla_Processing/Processing%20Bangla%20Word.ipynb
print(to_string([34, 50, 31, 54, 29, 54, 37, 44, 32, 44, 30, 54, 37, 44, 58], rs_borno));
# Out:
# বন্দ্যোপাধ্যায়

# %% [markdown]
# # Create Model object (BLSTM + CTC)
#
# ---
#
# Define LSTM Cell

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
def lstm_cell(is_training, hidden_size, dropout):
    cell = tf.contrib.rnn.LSTMCell(num_units = hidden_size, forget_bias=1.0, name = 'LSTM');
    if is_training and dropout < 1:
        cell = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=dropout)
    return cell

# %% [markdown]
# Create the model as a class

# %%
class Model(object):
    #constructor
    def __init__(self, is_training, batch_size, num_steps, hidden_size, no_of_output_labels, num_layers, dropout = 0.4, init_scale = 0.05):
        self.is_training = is_training;
        
        self.batch_size = batch_size;
        self.num_steps = num_steps;
        self.hidden_size = hidden_size;
        self.num_layers = num_layers;
        self.snap_id = 0;
        
        with tf.name_scope("Input"):
            self.inputs = tf.placeholder(tf.float32, shape=(self.batch_size, self.num_steps, 9));
        
        with tf.name_scope("Dropout"):
            if(is_training and dropout < 1):
                self.inputs = tf.nn.dropout(self.inputs, dropout);
        
        #setup Long Short Term Memory Network
        
        
        with tf.name_scope("LSTM_cell"):
            #create an LSTM Cell
            cells = [lstm_cell(is_training, hidden_size, dropout) for _ in range(num_layers)] # 2 layers
            # stack basic cells
            stacked = tf.contrib.rnn.MultiRNNCell(cells, state_is_tuple=True)
            
        with tf.name_scope("BLSTM_layer"):   
            # bidirectional RNN
            # BxTxF -> BxTx2H
            ((fw, bw), _) = tf.nn.bidirectional_dynamic_rnn(cell_fw=stacked, cell_bw=stacked, inputs=self.inputs, dtype=self.inputs.dtype)

            #concatenate the forward and backward output
            #tf.concat(data, 2) concatenates dimention no. 2
            #tf.expand_dims(data, 2) creates a new dimention at position 2 (done because of CTC ouptup layer)
            #tus BxTxH + BxTxH -> BxTx2H -> BxTx1X2H
            concat_out = tf.expand_dims(tf.concat([fw, bw], 2), 2);



            #reshape the output into BxTx1x2H -> (BxTx1)x2H -> BT1x2H to perform the affine transform
            concat_out = tf.reshape(concat_out, [-1, 2*hidden_size]);
        
        
        with tf.name_scope("Affine_Transform"):
            # Perform Affine Transform
            # Truncated normal with mean 0 and std_dev = 0.1   2HxC
            w = tf.Variable(tf.truncated_normal([2*hidden_size, no_of_output_labels+1], stddev = 0.1));
            # Zero bias initialization       C
            b = tf.Variable(tf.constant(0.1, shape = [no_of_output_labels+1]));
            # doing the affine projection BT1x2H * 2HxC + C -> BT1xC
            logits = tf.matmul(concat_out, w) + b;

            tf.summary.histogram('logits', logits);
        
            # reshaping back to original shape
            # BT1xC -> BxTxC
            logits = tf.reshape(logits, [self.batch_size, self.num_steps, (no_of_output_labels+1)]);
        
        
        
        #no need to use softmax activation because tensorflow CTC loss automatically performs softmax operation
        #setting up CTC
        #create CTC loss and decoder
        
        #first CTC requires an input of shape[TxBxC] (time major) , so perform a transpose
        # BxTxC -> TxBxC
        
        with tf.name_scope("Cost_calculation"):
            logits = tf.transpose(logits, [1, 0, 2]);
            self.gtTexts = tf.SparseTensor(
                tf.placeholder(tf.int64, shape = [None, 2]), #indices
                tf.placeholder(tf.int32,shape = [None]),     #Values
                tf.placeholder(tf.int64, shape = [2])        #shape
            )
            #calculate CTC loss for a batch
            self.seqLen = tf.placeholder(tf.int32, [None]) # dimention = batch_size
            loss = tf.nn.ctc_loss(
                labels = self.gtTexts,
                inputs = logits,
                sequence_length = self.seqLen,
                ctc_merge_repeated = True
            )

            #setup cost function for training

            self.cost = tf.reduce_mean(loss);
            tf.summary.scalar('cost', self.cost);
            
        with tf.name_scope("Decoder"):
            #setup decoder
            self.decoder = tf.nn.ctc_beam_search_decoder(inputs = logits, sequence_length = self.seqLen, beam_width = 80, merge_repeated = False)
        
        
        #setup gradient descent optimzer and train operation
        with tf.name_scope("Train"):
            self.batchesTrained = 0
            self.learning_rate = tf.placeholder(tf.float32, shape=[])
            self.train_op = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.cost)
        
        
        #setup tensorflow saver and session
        print("Initializing tensorflow");
        print('Python: '+sys.version)
        print('Tensorflow: '+tf.__version__)
        
        with tf.name_scope("Save_model"):
            self.sess = tf.Session();

            self.saver = tf.train.Saver();
            model_dir = "model/";
            latest_snapshot = tf.train.latest_checkpoint(model_dir);

            self.merged = tf.summary.merge_all();

            if latest_snapshot:
                print("init with stored values from " + latest_snapshot);
                self.saver.restore(self.sess, latest_snapshot);
            else:
                print("init with new values");
                self.sess.run(tf.global_variables_initializer());
        
    
    
    def train_batch(self, batch_input, batch_output):
        #feed batch to nn to train it
        #recay learning rate
        rate = 0.01 if self.batchesTrained < 10 else (0.001 if self.batchesTrained < 10000 else 0.0001)
        (cost, _, summ) = self.sess.run([self.cost, self.train_op, self.merged],feed_dict = {self.inputs : batch_input,
                                                                            self.gtTexts : batch_output,
                                                                            self.seqLen : [self.num_steps] * self.batch_size,
                                                                            self.learning_rate : rate})
        self.batchesTrained += 1;
        return cost, summ;
    
    def validate_batch(self, batch_input):
        #feed input to rnn and apply decoder
        #initial state
        
        decoded = self.sess.run([self.decoder], feed_dict = {self.inputs : batch_input,
                                                        self.seqLen : [self.num_steps] * self.batch_size
                                                       });
        return self.to_text(decoded);

    def to_text(self, ctc_output):
        #extracts text output from ctc decoder output
        
        encodedStr = [[] for _ in range(self.batch_size)];
        
        decoded = ctc_output[0][0][0] #ctc output returns a tuple(decoded, neg_sum_logits) where decoded is a sparse tensor
        # go over all indices
        #print(decoded.dense_shape);
        for(idx, idx2d) in enumerate(decoded.indices):
            label = decoded.values[idx];
            
            batch_element = idx2d[0];
            time_step = idx2d[1];
            
            encodedStr[batch_element].append(label);
        
        return encodedStr;
    
    def save(self):
        #save model
        self.snap_id += 1;
        self.saver.save(self.sess, 'model/snapshot', global_step = self.snap_id);

# %% [markdown]
# #Create training funciton
#
# ---

# %%
def train_model(batch_size, input_word, output_label, input_word_test, output_label_test):
    m = Model(is_training = True, batch_size = batch_size, num_steps = 64, hidden_size =512, no_of_output_labels = 59, num_layers = 3);
    #initialize writer
    writer = tf.summary.FileWriter(LOGDIR);
    writer.add_graph(m.sess.graph);
    best_error_rate = float('inf');
    #best_error_rate = .26;
    no_improvement_since = 0;
    no_improvement_limit = 10;
    epoch_list = list();
    error_list = list();
    word_accu_list = list();
    
    epoch = 0;
    while True:

        epoch += 1;
        print("Epoch ",epoch);
        train_ind = 0;


        while train_ind + batch_size <= len(input_word):
            input_data, output_data = input_word[train_ind : train_ind + batch_size], toSparse(output_label[train_ind : train_ind + batch_size]);
            train_ind += batch_size;
            #print(current_state_fw);
            #print(current_state_bw);
            cost, summ = m.train_batch(input_data, output_data);
            if(epoch % 15):writer.add_summary(summ, epoch)
            #cost  = m.train_batch_r(sess, input_data, output_data);
            print("cost is", cost);
        
        
        #evaluate every 15 epochs
        if(epoch % 15 == 0):
            #evaluate
            train_ind = 0;
            correct_word = 0;
            errors = 0;
            total_char = 0;
            total_word = 0;
            while train_ind + batch_size <= len(input_word_test):
                iw = input_word_test[train_ind : train_ind + batch_size];
                ol = output_label_test[train_ind : train_ind + batch_size];

                input_data, output_data = iw, toSparse(ol);

                train_ind += batch_size;

                encodedString = m.validate_batch(input_data);
                #encodedString = m.validate_batch_r(sess, input_data);



                for _ in range(batch_size):
                    #calculate error rate
                    recog = to_string(encodedString[_], rs_borno);
                    orig = to_string(ol[_], rs_borno);
                    dist = editdistance.eval(recog, orig);


                    #print("recognized -> original");
                    #print(recog," -> ", orig, "    edit distance is : ",dist);

                    if(dist==0):correct_word+=1;
                    else:
                        errors += dist;

                    total_char += len(orig);
                    total_word += 1;
            
            print("total ", errors, " errors found");
            error_rate = errors/total_char;
            word_accu = correct_word/total_word;
            
            epoch_list.append(epoch);
            error_list.append(error_rate);
            word_accu_list.append(word_accu);
            
    
            print("error rate is ",error_rate," and best error rate is ", best_error_rate);
            if(error_rate < best_error_rate):
                print("improvement found");
                print("Updating error rate to ", error_rate);
                best_error_rate = error_rate;
                no_improvement_since = 0;
                print("saving model");
                m.save();
                print("snapid is ", m.snap_id);
                
                myFiletste = "epoch_list.txt";
                myFiletster = "error_list.txt";
                myFiletstac = "word_accu_list.txt";
                with open(myFiletste, 'wb') as f:
                    pickle.dump(epoch_list, f);
                    print("Epoch list SuccessFully Saved");
                with open(myFiletster, 'wb') as f:
                    pickle.dump(error_list, f);
                    print("Error list SuccessFully Saved");
                with open(myFiletstac, 'wb') as f:
                    pickle.dump(word_accu_list, f);
                    print("Word accuracy list SuccessFully Saved");
            else:
                print("not improved");
                no_improvement_since += 1;


            if(no_improvement_since > no_improvement_limit):
                print("no improvement since %d epochs. Training stopped." % no_improvement_limit);
                break;

# %% [markdown]
# Finally train the model

# %%
tf.reset_default_graph();
train_model(155, train_input, train_output, test_input, test_output);
# Out:
# Initializing tensorflow
# Python: 3.6.6 (default, Sep 12 2018, 18:26:19)
# [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]]
# Tensorflow: 1.12.0
# init with stored values from model/snapshot-19
# INFO:tensorflow:Restoring parameters from model/snapshot-19
# Epoch  1
# cost is 0.025387045
# cost is 0.13566579
# cost is 16.613647
# cost is 317.1093
# cost is 114.39018
# cost is 192.7589
# Epoch  2
# cost is 54.959465
# cost is 37.64212
# cost is 24.198843
# cost is 35.195652
# cost is 31.615791
# cost is 24.788197
# Epoch  3
# cost is 17.659006
# cost is 19.685343
# cost is 19.631844
# cost is 22.225426
# cost is 28.257774
# cost is 22.67678
# Epoch  4
# cost is 15.542568
# cost is 17.495049
# cost is 17.809177
# cost is 20.329945
# cost is 24.611374
# cost is 19.873837
# Epoch  5
# cost is 13.978037
# cost is 15.299674
# cost is 16.271904
# cost is 19.179058
# cost is 22.686417
# cost is 19.015793
# Epoch  6
# cost is 12.936294
# cost is 14.762752
# cost is 15.378717
# cost is 18.229757
# cost is 20.414429
# cost is 17.544302
# Epoch  7
# cost is 12.787001
# cost is 13.975999
# cost is 14.443079
# cost is 18.02099
# cost is 18.903633
# cost is 16.667694
# Epoch  8
# cost is 12.039006
# cost is 13.73435
# cost is 14.412297
# cost is 17.819727
# cost is 17.899271
# cost is 15.725231
# Epoch  9
# cost is 12.057283
# cost is 13.730742
# cost is 14.830424
# cost is 17.478456
# cost is 18.014494
# cost is 15.726217
# Epoch  10
# cost is 11.686586
# cost is 13.194518
# cost is 14.422629
# cost is 17.057447
# cost is 17.025362
# cost is 15.412958
# Epoch  11
# cost is 11.765727
# cost is 12.811569
# cost is 14.6713505
# cost is 16.534857
# cost is 16.32658
# cost is 14.984561
# Epoch  12
# cost is 10.996311
# cost is 12.536253
# cost is 14.366898
# cost is 16.191698
# cost is 16.257872
# cost is 14.379407
# Epoch  13
# cost is 11.379018
# cost is 12.438077
# cost is 14.318892
# cost is 16.158669
# cost is 16.228
# cost is 14.227919
# Epoch  14
# cost is 11.256241
# cost is 12.253353
# cost is 13.887892
# cost is 15.632206
# cost is 15.879858
# cost is 13.624816
# Epoch  15
# cost is 11.064582
# cost is 12.183031
# cost is 13.64626
# cost is 15.627775
# cost is 16.21472
# cost is 13.943862
# total  1676  errors found
# error rate is  0.8938666666666667  and best error rate is  inf
# improvement found
# Updating error rate to  0.8938666666666667
# saving model
# snapid is  1
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  16
# cost is 10.774832
# cost is 12.121996
# cost is 13.620054
# cost is 15.405768
# cost is 15.159816
# cost is 13.5057535
# Epoch  17
# cost is 10.775233
# cost is 11.732093
# cost is 13.453196
# cost is 15.032306
# cost is 15.270769
# cost is 13.335732
# Epoch  18
# cost is 10.716655
# cost is 11.596429
# cost is 13.498004
# cost is 15.459918
# cost is 15.442739
# cost is 13.210329
# Epoch  19
# cost is 10.5863085
# cost is 11.845154
# cost is 12.965725
# cost is 14.916122
# cost is 14.899586
# cost is 12.861529
# Epoch  20
# cost is 10.463255
# cost is 11.679312
# cost is 13.084757
# cost is 15.095889
# cost is 15.855475
# cost is 13.355532
# Epoch  21
# cost is 10.305148
# cost is 11.5074625
# cost is 12.794615
# cost is 14.716103
# cost is 14.369288
# cost is 12.705353
# Epoch  22
# cost is 10.231322
# cost is 11.404822
# cost is 12.89902
# cost is 14.284701
# cost is 14.306196
# cost is 12.414555
# Epoch  23
# cost is 10.2046
# cost is 11.804439
# cost is 12.813825
# cost is 14.51877
# cost is 14.217865
# cost is 12.537738
# Epoch  24
# cost is 10.329493
# cost is 11.412426
# cost is 12.641027
# cost is 14.281893
# cost is 14.395919
# cost is 12.407444
# Epoch  25
# cost is 10.46538
# cost is 11.457273
# cost is 12.545042
# cost is 13.996087
# cost is 14.058356
# cost is 11.951694
# Epoch  26
# cost is 10.092334
# cost is 11.151369
# cost is 12.230913
# cost is 13.6258335
# cost is 13.8730755
# cost is 12.412144
# Epoch  27
# cost is 10.543923
# cost is 11.172597
# cost is 12.62426
# cost is 13.843721
# cost is 14.092517
# cost is 11.75946
# Epoch  28
# cost is 10.06878
# cost is 11.220333
# cost is 12.414012
# cost is 13.568361
# cost is 13.77408
# cost is 11.909769
# Epoch  29
# cost is 10.251944
# cost is 11.894157
# cost is 12.389113
# cost is 13.557025
# cost is 13.853823
# cost is 11.753517
# Epoch  30
# cost is 9.877828
# cost is 11.214979
# cost is 12.201535
# cost is 13.214904
# cost is 13.644574
# cost is 11.529464
# total  1618  errors found
# error rate is  0.8629333333333333  and best error rate is  0.8938666666666667
# improvement found
# Updating error rate to  0.8629333333333333
# saving model
# snapid is  2
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  31
# cost is 9.875855
# cost is 11.200973
# cost is 11.939562
# cost is 13.158652
# cost is 13.463118
# cost is 11.760677
# Epoch  32
# cost is 9.813001
# cost is 11.230203
# cost is 12.038463
# cost is 13.051547
# cost is 13.834095
# cost is 13.110532
# Epoch  33
# cost is 9.777138
# cost is 11.027058
# cost is 12.237626
# cost is 13.242436
# cost is 13.501797
# cost is 11.850491
# Epoch  34
# cost is 9.642766
# cost is 10.894113
# cost is 12.004965
# cost is 12.913388
# cost is 13.220106
# cost is 12.2019205
# Epoch  35
# cost is 9.944699
# cost is 10.505461
# cost is 12.01386
# cost is 12.6210575
# cost is 13.173505
# cost is 11.839065
# Epoch  36
# cost is 9.493428
# cost is 10.655679
# cost is 11.893231
# cost is 12.720873
# cost is 13.276947
# cost is 11.695597
# Epoch  37
# cost is 9.73902
# cost is 10.838802
# cost is 11.712538
# cost is 12.557144
# cost is 13.0171385
# cost is 11.344358
# Epoch  38
# cost is 9.446202
# cost is 10.462437
# cost is 11.53239
# cost is 12.479793
# cost is 13.870155
# cost is 13.557586
# Epoch  39
# cost is 9.335304
# cost is 10.360303
# cost is 11.613118
# cost is 12.386736
# cost is 12.862013
# cost is 11.420486
# Epoch  40
# cost is 9.23348
# cost is 10.197697
# cost is 11.554822
# cost is 11.986623
# cost is 12.808983
# cost is 11.483865
# Epoch  41
# cost is 9.234682
# cost is 10.079137
# cost is 11.369
# cost is 12.005228
# cost is 13.217061
# cost is 11.332271
# Epoch  42
# cost is 9.365026
# cost is 10.244726
# cost is 10.889098
# cost is 11.969199
# cost is 12.804779
# cost is 11.256967
# Epoch  43
# cost is 9.008852
# cost is 9.998958
# cost is 11.247409
# cost is 12.045385
# cost is 13.30705
# cost is 11.8706255
# Epoch  44
# cost is 8.754568
# cost is 9.852585
# cost is 11.060597
# cost is 11.346912
# cost is 12.937104
# cost is 11.811275
# Epoch  45
# cost is 8.877316
# cost is 10.344081
# cost is 11.084722
# cost is 11.543038
# cost is 12.796982
# cost is 10.810122
# total  1557  errors found
# error rate is  0.8304  and best error rate is  0.8629333333333333
# improvement found
# Updating error rate to  0.8304
# saving model
# snapid is  3
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  46
# cost is 9.496056
# cost is 9.928751
# cost is 10.839609
# cost is 10.851888
# cost is 12.080577
# cost is 11.233991
# Epoch  47
# cost is 8.839015
# cost is 9.7641735
# cost is 11.063806
# cost is 11.055286
# cost is 12.386165
# cost is 11.205971
# Epoch  48
# cost is 8.608808
# cost is 9.490493
# cost is 10.611389
# cost is 11.114482
# cost is 12.227459
# cost is 10.780531
# Epoch  49
# cost is 9.007534
# cost is 10.014251
# cost is 11.001331
# cost is 11.006326
# cost is 12.089484
# cost is 11.266388
# Epoch  50
# cost is 8.091886
# cost is 9.595344
# cost is 10.595832
# cost is 10.753578
# cost is 11.71472
# cost is 10.772767
# Epoch  51
# cost is 7.8063145
# cost is 9.3113985
# cost is 10.334392
# cost is 10.633936
# cost is 11.849421
# cost is 10.620457
# Epoch  52
# cost is 8.153408
# cost is 9.437312
# cost is 9.996292
# cost is 10.210118
# cost is 21.197786
# cost is 11.649208
# Epoch  53
# cost is 9.30166
# cost is 9.2568245
# cost is 10.371484
# cost is 10.696934
# cost is 12.026577
# cost is 10.378539
# Epoch  54
# cost is 8.581244
# cost is 9.347749
# cost is 9.760771
# cost is 9.835289
# cost is 11.668719
# cost is 10.170293
# Epoch  55
# cost is 8.270683
# cost is 9.493398
# cost is 9.629746
# cost is 9.678619
# cost is 11.719819
# cost is 10.288104
# Epoch  56
# cost is 7.906428
# cost is 8.950838
# cost is 9.449559
# cost is 9.625627
# cost is 11.829454
# cost is 11.100646
# Epoch  57
# cost is 7.78089
# cost is 8.698929
# cost is 9.520425
# cost is 9.430468
# cost is 11.172658
# cost is 10.496209
# Epoch  58
# cost is 9.167
# cost is 9.426857
# cost is 9.514921
# cost is 9.193775
# cost is 10.848879
# cost is 10.015147
# Epoch  59
# cost is 8.330148
# cost is 8.876375
# cost is 9.382471
# cost is 9.35212
# cost is 11.1767025
# cost is 9.815773
# Epoch  60
# cost is 8.0104265
# cost is 8.975185
# cost is 9.226005
# cost is 8.86355
# cost is 10.648387
# cost is 9.89825
# total  1398  errors found
# error rate is  0.7456  and best error rate is  0.8304
# improvement found
# Updating error rate to  0.7456
# saving model
# snapid is  4
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  61
# cost is 7.653208
# cost is 8.955586
# cost is 9.342332
# cost is 8.554249
# cost is 11.315887
# cost is 11.015814
# Epoch  62
# cost is 7.888343
# cost is 8.524523
# cost is 8.769207
# cost is 8.722818
# cost is 10.2810545
# cost is 10.2631855
# Epoch  63
# cost is 8.052052
# cost is 9.029383
# cost is 9.143172
# cost is 8.347866
# cost is 10.257736
# cost is 9.348088
# Epoch  64
# cost is 9.728934
# cost is 8.984628
# cost is 9.040341
# cost is 8.664799
# cost is 11.271685
# cost is 10.959113
# Epoch  65
# cost is 7.4460416
# cost is 8.222075
# cost is 8.828597
# cost is 8.159663
# cost is 10.031858
# cost is 10.260514
# Epoch  66
# cost is 7.977695
# cost is 8.291004
# cost is 8.461312
# cost is 7.73908
# cost is 9.697537
# cost is 9.257331
# Epoch  67
# cost is 7.9679184
# cost is 8.6085825
# cost is 8.677117
# cost is 8.101251
# cost is 10.304817
# cost is 9.530215
# Epoch  68
# cost is 7.533036
# cost is 8.069867
# cost is 8.347422
# cost is 8.321316
# cost is 9.822347
# cost is 9.412015
# Epoch  69
# cost is 7.0955844
# cost is 7.9883413
# cost is 8.352265
# cost is 7.388782
# cost is 9.353016
# cost is 10.002436
# Epoch  70
# cost is 6.85807
# cost is 8.052517
# cost is 7.9578757
# cost is 7.2891555
# cost is 9.089337
# cost is 8.921301
# Epoch  71
# cost is 8.1822195
# cost is 7.6077485
# cost is 8.128271
# cost is 8.35478
# cost is 9.104033
# cost is 9.133196
# Epoch  72
# cost is 6.9178047
# cost is 7.655171
# cost is 7.723328
# cost is 7.3690176
# cost is 9.356267
# cost is 8.75621
# Epoch  73
# cost is 6.77536
# cost is 8.044115
# cost is 7.209702
# cost is 7.1157575
# cost is 8.885919
# cost is 8.223974
# Epoch  74
# cost is 7.267537
# cost is 7.7136908
# cost is 8.666208
# cost is 7.4721146
# cost is 8.463987
# cost is 8.903731
# Epoch  75
# cost is 6.5980144
# cost is 7.6825213
# cost is 8.509823
# cost is 7.183474
# cost is 8.657125
# cost is 9.109572
# total  1210  errors found
# error rate is  0.6453333333333333  and best error rate is  0.7456
# improvement found
# Updating error rate to  0.6453333333333333
# saving model
# snapid is  5
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  76
# cost is 7.0053663
# cost is 7.0236754
# cost is 6.8227186
# cost is 6.9558334
# cost is 9.3061695
# cost is 9.840751
# Epoch  77
# cost is 6.2214193
# cost is 7.2891245
# cost is 6.714387
# cost is 7.2270713
# cost is 8.579287
# cost is 8.627337
# Epoch  78
# cost is 6.3084598
# cost is 7.894024
# cost is 7.09988
# cost is 6.9572344
# cost is 7.8693657
# cost is 7.71925
# Epoch  79
# cost is 7.0346766
# cost is 6.951687
# cost is 6.9149747
# cost is 6.5204635
# cost is 7.88512
# cost is 8.119933
# Epoch  80
# cost is 6.412683
# cost is 6.835829
# cost is 6.359748
# cost is 5.9749904
# cost is 7.4288607
# cost is 7.072531
# Epoch  81
# cost is 6.0513577
# cost is 7.235428
# cost is 7.123599
# cost is 7.0193696
# cost is 8.250392
# cost is 8.4359
# Epoch  82
# cost is 6.9051995
# cost is 6.711416
# cost is 7.005863
# cost is 6.1558256
# cost is 7.184779
# cost is 6.549204
# Epoch  83
# cost is 5.95144
# cost is 7.200459
# cost is 6.1567335
# cost is 6.0977144
# cost is 6.4547095
# cost is 6.004842
# Epoch  84
# cost is 6.139738
# cost is 6.8982997
# cost is 6.3876057
# cost is 5.524829
# cost is 6.6520596
# cost is 6.1601334
# Epoch  85
# cost is 5.6405554
# cost is 7.1478486
# cost is 5.8049417
# cost is 5.0285635
# cost is 7.068856
# cost is 6.8645077
# Epoch  86
# cost is 6.7419314
# cost is 7.4129953
# cost is 7.008452
# cost is 5.7232356
# cost is 7.44891
# cost is 7.710895
# Epoch  87
# cost is 6.095932
# cost is 6.082523
# cost is 5.6097646
# cost is 5.277917
# cost is 6.3098392
# cost is 6.070986
# Epoch  88
# cost is 6.4639606
# cost is 5.858847
# cost is 6.0597663
# cost is 6.084194
# cost is 6.6015406
# cost is 8.0118885
# Epoch  89
# cost is 5.6269555
# cost is 6.426238
# cost is 5.6712375
# cost is 4.8562875
# cost is 5.5518494
# cost is 5.4815097
# Epoch  90
# cost is 6.167138
# cost is 6.440368
# cost is 5.596253
# cost is 5.217969
# cost is 6.0233617
# cost is 5.4703393
# total  1103  errors found
# error rate is  0.5882666666666667  and best error rate is  0.6453333333333333
# improvement found
# Updating error rate to  0.5882666666666667
# saving model
# snapid is  6
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  91
# cost is 4.977459
# cost is 6.234011
# cost is 5.5951285
# cost is 4.818921
# cost is 5.9791937
# cost is 5.3158393
# Epoch  92
# cost is 5.169707
# cost is 6.490405
# cost is 5.464345
# cost is 4.600899
# cost is 5.4178452
# cost is 5.7073054
# Epoch  93
# cost is 5.3106294
# cost is 6.168186
# cost is 5.072218
# cost is 4.518191
# cost is 5.126961
# cost is 5.6973286
# Epoch  94
# cost is 5.564904
# cost is 6.0960307
# cost is 5.522315
# cost is 4.595806
# cost is 6.360899
# cost is 6.5322633
# Epoch  95
# cost is 4.2525063
# cost is 6.1172276
# cost is 5.0157022
# cost is 4.4383087
# cost is 5.1110964
# cost is 4.620723
# Epoch  96
# cost is 4.454404
# cost is 5.6574416
# cost is 5.159343
# cost is 4.111592
# cost is 4.775964
# cost is 4.150036
# Epoch  97
# cost is 4.0252957
# cost is 4.8715878
# cost is 6.19133
# cost is 5.008968
# cost is 5.0512023
# cost is 7.1328726
# Epoch  98
# cost is 4.900123
# cost is 4.960581
# cost is 5.8293214
# cost is 4.4651613
# cost is 4.628476
# cost is 4.120367
# Epoch  99
# cost is 3.9968617
# cost is 4.437882
# cost is 5.0933967
# cost is 4.902322
# cost is 4.751821
# cost is 4.5519648
# Epoch  100
# cost is 4.2167735
# cost is 5.647657
# cost is 5.6495676
# cost is 4.102065
# cost is 4.252507
# cost is 5.349424
# Epoch  101
# cost is 3.7838528
# cost is 4.8547363
# cost is 4.858563
# cost is 3.9592834
# cost is 3.7958279
# cost is 4.0936737
# Epoch  102
# cost is 4.129
# cost is 4.18865
# cost is 4.4934216
# cost is 3.7693336
# cost is 3.845629
# cost is 4.7571287
# Epoch  103
# cost is 4.3555174
# cost is 4.3492165
# cost is 4.325299
# cost is 3.8143957
# cost is 3.6126359
# cost is 3.8300812
# Epoch  104
# cost is 3.7854517
# cost is 4.0021467
# cost is 4.648961
# cost is 3.6582224
# cost is 4.0688696
# cost is 3.9562123
# Epoch  105
# cost is 3.664549
# cost is 3.9451964
# cost is 4.2445827
# cost is 3.8362958
# cost is 3.4646769
# cost is 3.6760159
# total  992  errors found
# error rate is  0.5290666666666667  and best error rate is  0.5882666666666667
# improvement found
# Updating error rate to  0.5290666666666667
# saving model
# snapid is  7
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  106
# cost is 3.8297462
# cost is 4.1319118
# cost is 4.1582804
# cost is 3.1964946
# cost is 4.0695744
# cost is 3.6755311
# Epoch  107
# cost is 3.8339517
# cost is 3.7221878
# cost is 3.3965533
# cost is 4.1926656
# cost is 4.2764854
# cost is 3.324183
# Epoch  108
# cost is 3.2736495
# cost is 4.2056093
# cost is 3.6834674
# cost is 3.58154
# cost is 5.12867
# cost is 7.1831975
# Epoch  109
# cost is 3.7922292
# cost is 3.9327905
# cost is 3.3958642
# cost is 2.5915859
# cost is 3.2369816
# cost is 2.638797
# Epoch  110
# cost is 2.9761405
# cost is 3.199522
# cost is 2.9660249
# cost is 2.6423354
# cost is 2.913201
# cost is 2.6579297
# Epoch  111
# cost is 2.8813698
# cost is 3.2430892
# cost is 3.4632182
# cost is 2.527994
# cost is 3.3156347
# cost is 3.134182
# Epoch  112
# cost is 3.1142154
# cost is 3.372263
# cost is 2.9530115
# cost is 2.281977
# cost is 3.6482158
# cost is 2.7766685
# Epoch  113
# cost is 3.449442
# cost is 2.8216052
# cost is 2.5020227
# cost is 2.1989152
# cost is 2.705723
# cost is 2.2514315
# Epoch  114
# cost is 2.4482436
# cost is 2.7666535
# cost is 2.5908234
# cost is 2.832704
# cost is 2.9455585
# cost is 2.8633213
# Epoch  115
# cost is 2.3675442
# cost is 3.2663941
# cost is 2.9708037
# cost is 1.9747547
# cost is 2.6509697
# cost is 1.9636759
# Epoch  116
# cost is 2.166241
# cost is 3.1908503
# cost is 3.8568943
# cost is 3.251866
# cost is 3.5659819
# cost is 3.594758
# Epoch  117
# cost is 2.535661
# cost is 2.9163873
# cost is 2.5843785
# cost is 1.8277161
# cost is 2.3182104
# cost is 2.0324054
# Epoch  118
# cost is 1.7718031
# cost is 2.1479113
# cost is 2.3782337
# cost is 1.9862199
# cost is 2.3659263
# cost is 2.586774
# Epoch  119
# cost is 1.8680038
# cost is 2.0920043
# cost is 2.4411209
# cost is 2.143521
# cost is 2.4535625
# cost is 2.2671092
# Epoch  120
# cost is 2.1897924
# cost is 2.1774535
# cost is 2.242931
# cost is 2.0833385
# cost is 1.9426544
# cost is 2.7296798
# total  746  errors found
# error rate is  0.39786666666666665  and best error rate is  0.5290666666666667
# improvement found
# Updating error rate to  0.39786666666666665
# saving model
# snapid is  8
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  121
# cost is 1.806996
# cost is 1.662068
# cost is 2.4075775
# cost is 2.1742191
# cost is 2.045317
# cost is 1.833058
# Epoch  122
# cost is 2.147978
# cost is 2.3730562
# cost is 1.9878156
# cost is 1.4330634
# cost is 1.7614427
# cost is 1.8012266
# Epoch  123
# cost is 1.5692254
# cost is 3.510607
# cost is 3.470748
# cost is 2.6532254
# cost is 2.5546966
# cost is 2.3333304
# Epoch  124
# cost is 1.644433
# cost is 1.7387134
# cost is 1.7716587
# cost is 1.9021758
# cost is 1.5414398
# cost is 1.4602293
# Epoch  125
# cost is 1.1857231
# cost is 1.4694523
# cost is 1.7018614
# cost is 1.3544213
# cost is 1.6318611
# cost is 1.4493834
# Epoch  126
# cost is 1.3153626
# cost is 1.422474
# cost is 1.7487333
# cost is 1.3763267
# cost is 1.483817
# cost is 1.6086993
# Epoch  127
# cost is 1.4134163
# cost is 1.9339983
# cost is 2.4139314
# cost is 2.4926903
# cost is 4.7862763
# cost is 4.9430847
# Epoch  128
# cost is 5.0035486
# cost is 2.160669
# cost is 1.9822636
# cost is 2.1164398
# cost is 1.9236078
# cost is 1.7151393
# Epoch  129
# cost is 1.1351644
# cost is 1.349524
# cost is 1.3601147
# cost is 1.0928787
# cost is 1.3828771
# cost is 1.3317822
# Epoch  130
# cost is 0.94344854
# cost is 1.2217801
# cost is 1.337812
# cost is 0.98427457
# cost is 1.2307225
# cost is 1.161481
# Epoch  131
# cost is 1.206374
# cost is 1.1800637
# cost is 1.2432953
# cost is 1.1877569
# cost is 1.7239311
# cost is 1.6366694
# Epoch  132
# cost is 1.7138777
# cost is 1.3677429
# cost is 1.5010575
# cost is 1.369863
# cost is 1.7569025
# cost is 1.8365705
# Epoch  133
# cost is 1.5633742
# cost is 1.6092211
# cost is 1.877403
# cost is 1.4081051
# cost is 1.2969133
# cost is 1.4713045
# Epoch  134
# cost is 0.84997696
# cost is 1.2199084
# cost is 1.3784032
# cost is 1.1941452
# cost is 1.4498796
# cost is 1.208947
# Epoch  135
# cost is 0.89014244
# cost is 1.0740871
# cost is 1.2288641
# cost is 0.9416367
# cost is 1.0719279
# cost is 1.2893646
# total  680  errors found
# error rate is  0.3626666666666667  and best error rate is  0.39786666666666665
# improvement found
# Updating error rate to  0.3626666666666667
# saving model
# snapid is  9
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  136
# cost is 1.0997915
# cost is 0.9257959
# cost is 1.0495508
# cost is 1.1834004
# cost is 1.4298522
# cost is 2.2965066
# Epoch  137
# cost is 2.744779
# cost is 3.4897127
# cost is 2.218803
# cost is 1.3680964
# cost is 1.9899966
# cost is 1.405532
# Epoch  138
# cost is 1.1728617
# cost is 1.6494654
# cost is 1.1561264
# cost is 1.1670566
# cost is 1.1875483
# cost is 1.1245486
# Epoch  139
# cost is 0.7184153
# cost is 0.5941664
# cost is 0.98747724
# cost is 0.96544975
# cost is 1.5998206
# cost is 1.1160476
# Epoch  140
# cost is 0.9986865
# cost is 1.0559362
# cost is 1.1925752
# cost is 1.339692
# cost is 1.1770203
# cost is 1.0919375
# Epoch  141
# cost is 0.8706975
# cost is 0.8561338
# cost is 1.0274765
# cost is 0.9129767
# cost is 0.8318567
# cost is 0.8934024
# Epoch  142
# cost is 0.8422448
# cost is 0.681581
# cost is 0.8269706
# cost is 0.80629253
# cost is 0.7677141
# cost is 1.0409862
# Epoch  143
# cost is 0.71362007
# cost is 0.8703962
# cost is 1.373127
# cost is 1.2799724
# cost is 1.7660239
# cost is 1.7268157
# Epoch  144
# cost is 0.8758903
# cost is 0.7852653
# cost is 1.1420716
# cost is 1.0120056
# cost is 1.1370463
# cost is 0.88513255
# Epoch  145
# cost is 0.5949014
# cost is 0.72647446
# cost is 0.79435515
# cost is 0.87722933
# cost is 0.8885749
# cost is 0.7767138
# Epoch  146
# cost is 0.5556256
# cost is 0.64315313
# cost is 0.94874465
# cost is 1.2819629
# cost is 1.1075722
# cost is 1.2240698
# Epoch  147
# cost is 2.3787992
# cost is 1.7996693
# cost is 1.0543841
# cost is 0.7282053
# cost is 1.0190145
# cost is 0.81298965
# Epoch  148
# cost is 0.77042
# cost is 0.59863096
# cost is 0.7329974
# cost is 0.66128266
# cost is 0.6686142
# cost is 0.6556131
# Epoch  149
# cost is 0.45534378
# cost is 0.48076442
# cost is 0.6625632
# cost is 0.87820935
# cost is 0.79484797
# cost is 0.77694017
# Epoch  150
# cost is 0.4773128
# cost is 0.49878117
# cost is 0.4786559
# cost is 0.7449832
# cost is 0.83832467
# cost is 0.8136864
# total  619  errors found
# error rate is  0.33013333333333333  and best error rate is  0.3626666666666667
# improvement found
# Updating error rate to  0.33013333333333333
# saving model
# snapid is  10
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  151
# cost is 0.70125985
# cost is 0.46957842
# cost is 0.854796
# cost is 0.7639321
# cost is 1.0567108
# cost is 1.5614038
# Epoch  152
# cost is 0.80815226
# cost is 0.6830601
# cost is 0.56518054
# cost is 0.68078643
# cost is 0.8179374
# cost is 0.664413
# Epoch  153
# cost is 0.45601147
# cost is 0.25190678
# cost is 0.83240247
# cost is 0.7158963
# cost is 0.5701332
# cost is 0.87674236
# Epoch  154
# cost is 1.2832633
# cost is 2.6322262
# cost is 2.5065012
# cost is 1.0270104
# cost is 0.88460773
# cost is 0.92695826
# Epoch  155
# cost is 0.7286176
# cost is 0.5736339
# cost is 0.67196107
# cost is 0.60292584
# cost is 0.43053672
# cost is 0.558578
# Epoch  156
# cost is 0.32468605
# cost is 0.32871705
# cost is 0.42724225
# cost is 0.68690294
# cost is 0.9455104
# cost is 1.6041492
# Epoch  157
# cost is 0.4120881
# cost is 0.50986284
# cost is 0.7856787
# cost is 0.69561565
# cost is 0.67449087
# cost is 0.9070761
# Epoch  158
# cost is 0.52452487
# cost is 0.49812272
# cost is 0.5689944
# cost is 0.63142
# cost is 0.46662283
# cost is 0.63960224
# Epoch  159
# cost is 0.3685272
# cost is 1.1646553
# cost is 2.259018
# cost is 1.3610268
# cost is 0.75928396
# cost is 1.0891658
# Epoch  160
# cost is 1.269627
# cost is 1.3551306
# cost is 1.1178218
# cost is 0.5757403
# cost is 0.70049876
# cost is 0.76547015
# Epoch  161
# cost is 0.33664697
# cost is 0.2671841
# cost is 0.49469635
# cost is 0.50633097
# cost is 0.49497503
# cost is 0.4811675
# Epoch  162
# cost is 0.24653372
# cost is 0.2491773
# cost is 0.3842697
# cost is 0.44673687
# cost is 0.4773571
# cost is 0.49471554
# Epoch  163
# cost is 0.24618289
# cost is 0.3435981
# cost is 0.33985543
# cost is 0.45479938
# cost is 0.42306873
# cost is 0.63324374
# Epoch  164
# cost is 0.2969621
# cost is 0.320108
# cost is 0.54280645
# cost is 0.5593297
# cost is 0.6058723
# cost is 0.66658264
# Epoch  165
# cost is 0.4150445
# cost is 0.42050037
# cost is 0.60125417
# cost is 0.67198414
# cost is 0.54486793
# cost is 0.92565054
# total  608  errors found
# error rate is  0.32426666666666665  and best error rate is  0.33013333333333333
# improvement found
# Updating error rate to  0.32426666666666665
# saving model
# snapid is  11
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  166
# cost is 0.8040058
# cost is 0.9315035
# cost is 0.96335894
# cost is 0.9245143
# cost is 0.66403717
# cost is 0.6032948
# Epoch  167
# cost is 0.8578112
# cost is 0.88636976
# cost is 1.4121178
# cost is 2.2958379
# cost is 3.9762862
# cost is 2.438594
# Epoch  168
# cost is 1.2647526
# cost is 0.5391157
# cost is 0.5193069
# cost is 0.6633821
# cost is 0.5226409
# cost is 0.6877759
# Epoch  169
# cost is 0.36024565
# cost is 0.23885562
# cost is 0.49533814
# cost is 0.47564748
# cost is 0.3800696
# cost is 0.47536665
# Epoch  170
# cost is 0.3375792
# cost is 0.18963885
# cost is 0.39031205
# cost is 0.46466425
# cost is 0.31736803
# cost is 0.43297428
# Epoch  171
# cost is 0.18338822
# cost is 0.22119986
# cost is 0.32012507
# cost is 0.3921897
# cost is 0.33284003
# cost is 0.3563932
# Epoch  172
# cost is 0.11113184
# cost is 0.09562053
# Epoch  269
# cost is 0.060868356
# cost is 0.06857911
# cost is 0.10503287
# cost is 0.23585042
# cost is 0.4674295
# cost is 1.3158548
# Epoch  270
# cost is 0.5553594
# cost is 0.47561094
# cost is 0.16890404
# cost is 0.44110128
# cost is 1.827046
# cost is 0.19717304
# total  438  errors found
# error rate is  0.2336  and best error rate is  0.2512
# improvement found
# Updating error rate to  0.2336
# saving model
# snapid is  15
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  271
# cost is 0.5805176
# cost is 0.07295325
# cost is 0.14144054
# cost is 0.15922391
# cost is 0.06663664
# cost is 0.10195508
# Epoch  272
# cost is 0.056170832
# cost is 0.058880184
# cost is 0.11407136
# cost is 0.13978271
# cost is 0.12378572
# cost is 0.1061932
# Epoch  273
# cost is 0.051091958
# cost is 0.035768278
# cost is 0.053769615
# cost is 0.1460318
# cost is 0.16124585
# cost is 0.20083134
# Epoch  274
# cost is 0.044373307
# cost is 0.050289072
# cost is 0.10237279
# cost is 0.101643115
# cost is 0.060076214
# cost is 0.0962675
# Epoch  275
# cost is 0.032509394
# cost is 0.02413868
# cost is 0.088987455
# cost is 0.08272992
# cost is 0.090743415
# cost is 0.104924746
# Epoch  276
# cost is 0.052617498
# cost is 0.050655384
# cost is 0.1181601
# cost is 0.28087017
# cost is 0.16884345
# cost is 0.18825571
# Epoch  277
# cost is 0.10666228
# cost is 0.10310275
# cost is 0.210093
# cost is 0.58089095
# cost is 1.1165023
# cost is 2.1797993
# Epoch  278
# cost is 1.1261889
# cost is 0.18282406
# cost is 0.21902557
# cost is 0.19521326
# cost is 0.22554696
# cost is 0.18642983
# Epoch  279
# cost is 0.16017072
# cost is 0.06574993
# cost is 0.19223869
# cost is 0.068997145
# cost is 0.09282559
# cost is 0.06466037
# Epoch  280
# cost is 0.039915737
# cost is 0.037510753
# cost is 0.08351561
# cost is 0.05648595
# cost is 0.061248608
# cost is 0.17583281
# Epoch  281
# cost is 0.04772227
# cost is 0.073985465
# cost is 0.1954939
# cost is 0.22935638
# cost is 0.15471679
# cost is 0.17295599
# Epoch  282
# cost is 0.07281243
# cost is 0.16535139
# cost is 0.11764751
# cost is 0.06967915
# cost is 0.101312146
# cost is 0.15274002
# Epoch  283
# cost is 0.11396775
# cost is 0.084727034
# cost is 0.14994106
# cost is 0.3892761
# cost is 0.2471638
# cost is 0.09211868
# Epoch  284
# cost is 0.09649433
# cost is 0.05373996
# cost is 0.06643248
# cost is 0.07991674
# cost is 0.06587387
# cost is 0.10479596
# Epoch  285
# cost is 0.053987797
# cost is 0.101077594
# cost is 0.06441655
# cost is 0.044724267
# cost is 0.04018796
# cost is 0.07386019
# total  383  errors found
# error rate is  0.20426666666666668  and best error rate is  0.2336
# improvement found
# Updating error rate to  0.20426666666666668
# saving model
# snapid is  16
# Epoch list SuccessFully Saved
# Error list SuccessFully Saved
# Word accuracy list SuccessFully Saved
# Epoch  286
# cost is 0.051259197
# cost is 0.08140453
# cost is 0.09652075
# cost is 0.0139537845
# cost is 0.12668473
# Epoch  763
# cost is 0.020675723
# cost is 0.023406742
# cost is 0.018202456
# cost is 0.037199892
# cost is 0.02305563
# cost is 0.01011336
# Epoch  764
# cost is 0.14211646
# cost is 0.010347346
# cost is 0.40520242
# cost is 0.030274188
# cost is 0.09970094
# cost is 0.1552614
# Epoch  765
# cost is 0.006483767
# cost is 0.009666936
# cost is 0.01486348
# cost is 0.036386605
# cost is 0.016048929
# cost is 0.011396451
# total  350  errors found
# error rate is  0.18666666666666668  and best error rate is  0.16853333333333334
# not improved
# no improvement since 10 epochs. Training stopped.

# %%
from google.colab import files
myfiles = [x[2] for x in os.walk('model/')];
print(myfiles[0]);
for file in myfiles[0]:
  files.download('model/'+file);
# Out:
# ['snapshot-18.meta', 'snapshot-19.data-00000-of-00001', 'snapshot-16.index', 'checkpoint', 'snapshot-16.data-00000-of-00001', 'snapshot-17.data-00000-of-00001', 'snapshot-15.meta', 'snapshot-19.meta', 'snapshot-15.data-00000-of-00001', 'snapshot-18.index', 'snapshot-17.index', 'snapshot-19.index', 'snapshot-18.data-00000-of-00001', 'snapshot-17.meta', 'snapshot-15.index', 'snapshot-16.meta']

# %% [markdown]
# #Test model
#
# ---
# Create testing function

# %%
def test_model(batch_size, input_test, output_test):
    m = Model(is_training = False, batch_size = batch_size, num_steps = 64, hidden_size =512, no_of_output_labels = 59, num_layers = 3);
    #evaluate
    train_ind = 0;
    correct_word = 0;
    errors = 0;
    total_char = 0;
    total_word = 0;
    input_word = input_test;
    output_label = output_test;
    while train_ind + batch_size <= len(input_word):
        iw = input_word[train_ind : train_ind + batch_size];
        ol = output_label[train_ind : train_ind + batch_size];

        input_data, output_data = iw, toSparse(ol);

        train_ind += batch_size;

        encodedString = m.validate_batch(input_data);
        #encodedString = m.validate_batch_r(sess, input_data);



        for _ in range(batch_size):
            #calculate error rate
            recog = to_string(encodedString[_], rs_borno);
            orig = to_string(ol[_], rs_borno);
            dist = editdistance.eval(recog, orig);


            print("recognized -> original");
            print(recog," -> ", orig, "    edit distance is : ",dist);

            if(dist==0):correct_word+=1;
            else:
                errors += dist;

            total_char += len(orig);
            total_word += 1;

    error_rate = errors/total_char;
    word_accu = correct_word/total_word;

    print("error rate is ",error_rate," and Word Accuracy is ", word_accu);

# %% [markdown]
# Call the test function

# %%
tf.reset_default_graph();
test_model(155, test_input, test_output);
# Out:
# Initializing tensorflow
# Python: 3.6.6 (default, Sep 12 2018, 18:26:19)
# [GCC 8.0.1 20180414 (experimental) [trunk revision 259383]]
# Tensorflow: 1.12.0
# init with stored values from model/snapshot-19
# INFO:tensorflow:Restoring parameters from model/snapshot-19
# recognized -> original
# আরেন  ->  আছো     edit distance is :  3
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# নছো  ->  আছো     edit distance is :  1
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আছের  ->  আছো     edit distance is :  2
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আহেত  ->  আছো     edit distance is :  3
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আছো  ->  আছো     edit distance is :  0
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আতামনি  ->  আপনি     edit distance is :  3
# recognized -> original
# ভাাসি  ->  আপনি     edit distance is :  4
# recognized -> original
# তোমারি  ->  আপনি     edit distance is :  5
# recognized -> original
# আনি  ->  আপনি     edit distance is :  1
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আনি  ->  আপনি     edit distance is :  1
# recognized -> original
# আপনি  ->  আপনি     edit distance is :  0
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমরেন  ->  আমার     edit distance is :  3
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# তোমার  ->  আমার     edit distance is :  2
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমনি  ->  আমার     edit distance is :  2
# recognized -> original
# আার  ->  আমার     edit distance is :  1
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমার  ->  আমার     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# রমি  ->  আমি     edit distance is :  1
# recognized -> original
# আপমি  ->  আমি     edit distance is :  1
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আনি  ->  আমি     edit distance is :  1
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আনি  ->  আমি     edit distance is :  1
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# খমি  ->  আমি     edit distance is :  1
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# আাম  ->  আমি     edit distance is :  2
# recognized -> original
# আমি  ->  আমি     edit distance is :  0
# recognized -> original
# কেমি  ->  আমি     edit distance is :  2
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# ডাই  ->  একটি     edit distance is :  4
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# আটি  ->  একটি     edit distance is :  2
# recognized -> original
# কেটি  ->  একটি     edit distance is :  2
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# একটি  ->  একটি     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# আবেন  ->  করবেন     edit distance is :  2
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# করবেন  ->  করবেন     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# মি  ->  কি     edit distance is :  1
# recognized -> original
# য়ি  ->  কি     edit distance is :  1
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কি  ->  কি     edit distance is :  0
# recognized -> original
# কেবেন  ->  কেমন     edit distance is :  2
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# ােন  ->  কেমন     edit distance is :  2
# recognized -> original
# দেবেন  ->  কেমন     edit distance is :  3
# recognized -> original
# কেরবেন  ->  কেমন     edit distance is :  3
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# কেবেন  ->  কেমন     edit distance is :  2
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# কেমন  ->  কেমন     edit distance is :  0
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# মান  ->  কোন     edit distance is :  2
# recognized -> original
# নাফ  ->  কোন     edit distance is :  3
# recognized -> original
# লোক  ->  কোন     edit distance is :  2
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# পুািন  ->  কোন     edit distance is :  4
# recognized -> original
# কেশেন  ->  কোন     edit distance is :  3
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# কোন  ->  কোন     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাত  ->  খাই     edit distance is :  1
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খইি  ->  খাই     edit distance is :  2
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# খাই  ->  খাই     edit distance is :  0
# recognized -> original
# ডাক  ->  ডাক     edit distance is :  0
# recognized -> original
# ডাক  ->  ডাক     edit distance is :  0
# recognized -> original
# ডাক  ->  ডাক     edit distance is :  0
# recognized -> original
# ভাত  ->  ডাক     edit distance is :  2
# recognized -> original
# খা  ->  ডাক     edit distance is :  2
# recognized -> original
# মান  ->  ডাক     edit distance is :  2
# recognized -> original
# ডাক  ->  ডাক     edit distance is :  0
# recognized -> original
# ডাক  ->  ডাক     edit distance is :  0
# recognized -> original
# ডাক  ->  ডাক     edit distance is :  0
# recognized -> original
# ডাক  ->  ডাক     edit distance is :  0
# recognized -> original
# ভাত  ->  ডাক     edit distance is :  2
# recognized -> original
# ডহিম  ->  ডাক     edit distance is :  3
# recognized -> original
# ডাক  ->  ডাক     edit distance is :  0
# recognized -> original
# ভাক  ->  ডাক     edit distance is :  1
# recognized -> original
# ডাক  ->  ডাক     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# ােত  ->  তুমি     edit distance is :  4
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# রমি  ->  তুমি     edit distance is :  2
# recognized -> original
# তুটি  ->  তুমি     edit distance is :  1
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# তুমি  ->  তুমি     edit distance is :  0
# recognized -> original
# াোকে  ->  তোমাকে     edit distance is :  3
# recognized -> original
# ববেন  ->  তোমাকে     edit distance is :  6
# recognized -> original
# তোাকে  ->  তোমাকে     edit distance is :  1
# recognized -> original
# মেলশকে  ->  তোমাকে     edit distance is :  4
# recognized -> original
# বেশকে  ->  তোমাকে     edit distance is :  4
# recognized -> original
# আমাকে  ->  তোমাকে     edit distance is :  2
# recognized -> original
# তোমাকে  ->  তোমাকে     edit distance is :  0
# recognized -> original
# তোমাকে  ->  তোমাকে     edit distance is :  0
# recognized -> original
# তোমাকে  ->  তোমাকে     edit distance is :  0
# recognized -> original
# তোাকে  ->  তোমাকে     edit distance is :  1
# recognized -> original
# মোর  ->  তোমাকে     edit distance is :  5
# recognized -> original
# পতুমাকে  ->  তোমাকে     edit distance is :  2
# recognized -> original
# তোমাকে  ->  তোমাকে     edit distance is :  0
# recognized -> original
# তেমাকে  ->  তোমাকে     edit distance is :  1
# recognized -> original
# তোমাকে  ->  তোমাকে     edit distance is :  0
# recognized -> original
# দেশেন  ->  দেশের     edit distance is :  1
# recognized -> original
# দেশের  ->  দেশের     edit distance is :  0
# recognized -> original
# দেবেন  ->  দেশের     edit distance is :  2
# recognized -> original
# দেবেন  ->  দেশের     edit distance is :  2
# recognized -> original
# দোর  ->  দেশের     edit distance is :  3
# recognized -> original
# দেশর  ->  দেশের     edit distance is :  1
# recognized -> original
# দেশের  ->  দেশের     edit distance is :  0
# recognized -> original
# দেশের  ->  দেশের     edit distance is :  0
# recognized -> original
# দেশের  ->  দেশের     edit distance is :  0
# recognized -> original
# লোন  ->  দেশের     edit distance is :  5
# recognized -> original
# দেশের  ->  দেশের     edit distance is :  0
# recognized -> original
# বশর  ->  দেশের     edit distance is :  3
# recognized -> original
# দেশের  ->  দেশের     edit distance is :  0
# recognized -> original
# দেশের  ->  দেশের     edit distance is :  0
# recognized -> original
# দেশের  ->  দেশের     edit distance is :  0
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নাফ  ->  নাম     edit distance is :  1
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# আাছম  ->  নাম     edit distance is :  2
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# ভাত  ->  নাম     edit distance is :  2
# recognized -> original
# নাম  ->  নাম     edit distance is :  0
# recognized -> original
# নিচ্ছি  ->  নিচ্ছি     edit distance is :  0
# recognized -> original
# নিচ্ছ  ->  নিচ্ছি     edit distance is :  1
# recognized -> original
# চ্ছি  ->  নিচ্ছি     edit distance is :  2
# recognized -> original
# নিেিছা  ->  নিচ্ছি     edit distance is :  3
# recognized -> original
# নিচ্ছ  ->  নিচ্ছি     edit distance is :  1
# recognized -> original
# নিচ্ছি  ->  নিচ্ছি     edit distance is :  0
# recognized -> original
# নিািয়  ->  নিচ্ছি     edit distance is :  4
# recognized -> original
# নিচ্ছি  ->  নিচ্ছি     edit distance is :  0
# recognized -> original
# নিচ্ছি  ->  নিচ্ছি     edit distance is :  0
# recognized -> original
# নিচ্ছি  ->  নিচ্ছি     edit distance is :  0
# recognized -> original
# নিচ্ছি  ->  নিচ্ছি     edit distance is :  0
# recognized -> original
# নিচ্ছ  ->  নিচ্ছি     edit distance is :  1
# recognized -> original
# নিচ্ছি  ->  নিচ্ছি     edit distance is :  0
# recognized -> original
# নিচ্ছি  ->  নিচ্ছি     edit distance is :  0
# recognized -> original
# নিচ্ছ  ->  নিচ্ছি     edit distance is :  1
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# আয়  ->  নয়     edit distance is :  1
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নাম  ->  নয়     edit distance is :  2
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# নস  ->  নয়     edit distance is :  1
# recognized -> original
# নয়  ->  নয়     edit distance is :  0
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# মাকে  ->  পারেন     edit distance is :  3
# recognized -> original
# পারে  ->  পারেন     edit distance is :  1
# recognized -> original
# পাাসি  ->  পারেন     edit distance is :  3
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# বেশের  ->  পারেন     edit distance is :  4
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# পারেন  ->  পারেন     edit distance is :  0
# recognized -> original
# পুািকে  ->  পুলিশকে     edit distance is :  2
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# পুািকে  ->  পুলিশকে     edit distance is :  2
# recognized -> original
# পুকে  ->  পুলিশকে     edit distance is :  3
# recognized -> original
# পরাকে  ->  পুলিশকে     edit distance is :  4
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# পশিকে  ->  পুলিশকে     edit distance is :  3
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# পুলিশকে  ->  পুলিশকে     edit distance is :  0
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# ব্টে  ->  বলতে     edit distance is :  2
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বতে  ->  বলতে     edit distance is :  1
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বকে  ->  বলতে     edit distance is :  2
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বলতে  ->  বলতে     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাংলাে  ->  বাংলা     edit distance is :  1
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বাা  ->  বাংলা     edit distance is :  2
# recognized -> original
# বাংলা  ->  বাংলা     edit distance is :  0
# recognized -> original
# বিদায়  ->  বিদায়     edit distance is :  0
# recognized -> original
# বিলতে  ->  বিদায়     edit distance is :  3
# recognized -> original
# বিাকে  ->  বিদায়     edit distance is :  3
# recognized -> original
# বিলনি  ->  বিদায়     edit distance is :  3
# recognized -> original
# বিলশকে  ->  বিদায়     edit distance is :  4
# recognized -> original
# বিদায়ক  ->  বিদায়     edit distance is :  1
# recognized -> original
# বায়  ->  বিদায়     edit distance is :  2
# recognized -> original
# বিদায়  ->  বিদায়     edit distance is :  0
# recognized -> original
# বিদায়  ->  বিদায়     edit distance is :  0
# recognized -> original
# বিদায়  ->  বিদায়     edit distance is :  0
# recognized -> original
# বিদায়  ->  বিদায়     edit distance is :  0
# recognized -> original
# বিদিায়  ->  বিদায়     edit distance is :  1
# recognized -> original
# বিদায়  ->  বিদায়     edit distance is :  0
# recognized -> original
# বিদায়  ->  বিদায়     edit distance is :  0
# recognized -> original
# বিদায়  ->  বিদায়     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ডাত  ->  ভাত     edit distance is :  1
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভাত  ->  ভাত     edit distance is :  0
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# ােবাসি  ->  ভালবাসি     edit distance is :  2
# recognized -> original
# ভলাস  ->  ভালবাসি     edit distance is :  3
# recognized -> original
# ভবাসি  ->  ভালবাসি     edit distance is :  2
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# আপসি  ->  ভালবাসি     edit distance is :  5
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# ভালবাসি  ->  ভালবাসি     edit distance is :  0
# recognized -> original
# নাষা  ->  ভাষা     edit distance is :  1
# recognized -> original
# ভনি  ->  ভাষা     edit distance is :  3
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# বা  ->  ভাষা     edit distance is :  3
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# মাষা  ->  ভাষা     edit distance is :  1
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# ভাষা  ->  ভাষা     edit distance is :  0
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# মলাফ  ->  মাফ     edit distance is :  1
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# নান  ->  মাফ     edit distance is :  2
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# ািন  ->  মাফ     edit distance is :  3
# recognized -> original
# না  ->  মাফ     edit distance is :  2
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# মাফ  ->  মাফ     edit distance is :  0
# recognized -> original
# যথেষ্ট  ->  যথেষ্ট     edit distance is :  0
# recognized -> original
# আমশের  ->  যথেষ্ট     edit distance is :  6
# recognized -> original
# যবেন  ->  যথেষ্ট     edit distance is :  4
# recognized -> original
# দেষ্ট  ->  যথেষ্ট     edit distance is :  2
# recognized -> original
# যথেষ্ট  ->  যথেষ্ট     edit distance is :  0
# recognized -> original
# আষ্ট  ->  যথেষ্ট     edit distance is :  3
# recognized -> original
# যষ্টে  ->  যথেষ্ট     edit distance is :  3
# recognized -> original
# যথেষ্ট  ->  যথেষ্ট     edit distance is :  0
# recognized -> original
# যথেষ্ট  ->  যথেষ্ট     edit distance is :  0
# recognized -> original
# যথেষ্ট  ->  যথেষ্ট     edit distance is :  0
# recognized -> original
# যথেথষ্ট  ->  যথেষ্ট     edit distance is :  1
# recognized -> original
# দেথষ্ট  ->  যথেষ্ট     edit distance is :  3
# recognized -> original
# যথেষ্ট  ->  যথেষ্ট     edit distance is :  0
# recognized -> original
# যথেষ্ট  ->  যথেষ্ট     edit distance is :  0
# recognized -> original
# যথেষ্ট  ->  যথেষ্ট     edit distance is :  0
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# বলাম  ->  রহিম     edit distance is :  3
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# রটি  ->  রহিম     edit distance is :  2
# recognized -> original
# রহম  ->  রহিম     edit distance is :  1
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# রহম  ->  রহিম     edit distance is :  1
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# রছেম  ->  রহিম     edit distance is :  2
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# রহিম  ->  রহিম     edit distance is :  0
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# যটে  ->  লোক     edit distance is :  3
# recognized -> original
# দোক  ->  লোক     edit distance is :  1
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# ােক  ->  লোক     edit distance is :  2
# recognized -> original
# ােক  ->  লোক     edit distance is :  2
# recognized -> original
# কেলাক  ->  লোক     edit distance is :  3
# recognized -> original
# লোক  ->  লোক     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# recognized -> original
# সে  ->  সে     edit distance is :  0
# error rate is  0.15413333333333334  and Word Accuracy is  0.7247311827956989

# %%
# !zip -r model.zip model
# Out:
#   adding: model/ (stored 0%)
#   adding: model/snapshot-18.meta (deflated 93%)
#   adding: model/snapshot-19.data-00000-of-00001 (deflated 6%)
#   adding: model/snapshot-16.index (deflated 49%)
#   adding: model/checkpoint (deflated 74%)
#   adding: model/snapshot-16.data-00000-of-00001 (deflated 7%)
#   adding: model/snapshot-17.data-00000-of-00001 (deflated 7%)
#   adding: model/snapshot-15.meta (deflated 93%)
#   adding: model/snapshot-19.meta (deflated 93%)
#   adding: model/snapshot-15.data-00000-of-00001 (deflated 7%)
#   adding: model/snapshot-18.index (deflated 49%)
#   adding: model/snapshot-17.index (deflated 49%)
#   adding: model/snapshot-19.index (deflated 49%)
#   adding: model/snapshot-18.data-00000-of-00001 (deflated 7%)
#   adding: model/snapshot-17.meta (deflated 93%)
#   adding: model/snapshot-15.index (deflated 49%)
#   adding: model/snapshot-16.meta (deflated 93%)

# %%
files.download('model.zip');
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 56540, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 721, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 800, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------
